# %%
import read_booli
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
overview = pd.read_csv('solna_rum3.csv')

# %%
overview
# Out:
#       Price  Area                     Address        Date  \
# 0   4700000  78.0   Anders Lundströms gata 14  2022-12-08
# 1   4150000  65.0               Pomonagatan 4  2022-12-14
# 2   5500000  85.0           Rosenborgsgatan 3  2023-01-18
# 3   3550000  74.0       Mäster Simons väg 11B  2023-01-19
# 4   3970000  80.0                  Frögatan 6  2023-02-01
# 5   3400000  77.5           Regementsgatan 54  2023-02-01
# 6   5320000  89.0   Gustav III:s Boulevard 78  2023-02-08
# 7   4930000  93.0    Gustav III:s Boulevard 5  2023-02-17
# 8   4650000  74.5            Banmästargatan 8  2023-02-22
# 9   2900000  71.0              Ballonggatan 9  2023-02-23
# 10  4725000  81.0       Signe Tillischgatan 2  2023-02-24
# 11  4720000  81.0  Gustav III:s Boulevard 117  2023-02-24
# 12  4850000  83.0           Rosenborgsgatan 9  2023-03-07
# 13  4750000  79.5  Gustav III:s Boulevard 153  2023-03-19
# 14  5035000  85.0  Gustav III:s Boulevard 129  2023-03-22
# ...

# %%
# Sample new data
new_data = {
    'Area': 81.0,
    'Rum': 3,
    'Avgift': 4293,
    'Built year': 2001,
    'Date': '2024-04-29',
    'Address': 'Gustav III:s Boulevard 29',
    'Policy rate' : '4.00',
    'Deposit rate' : '3.90',
    'Lending rate' : '4.10'

}

# Call the function to predict the house price
data = result
model_setting = read_booli.RandomForestRegressor(random_state=1, n_estimators=100, max_depth=10, min_samples_split=15) # , max_depth=10, min_samples_split=20, min_samples_leaf=10
train_rmse, test_rmse, predicted_price, lower_bound, upper_bound, model, X_train, X_test, y_train, y_test = read_booli.predict_house_price(data, new_data, model_setting)

# %%
# Print the results
print("Train RMSE:", round(train_rmse))
print("Test RMSE:", round(test_rmse))
print("Predicted Price:", round(predicted_price))
print("Lower Bound:", round(lower_bound))
print("Upper Bound:", round(upper_bound))
# Out:
# Train RMSE: 291363
# Test RMSE: 453034
# Predicted Price: 4648714
# Lower Bound: 4195680
# Upper Bound: 5101748

# %%
read_booli.print_feature_importance(model, X_train.columns)
# Out:
#                          Feature  Importance
# 0                           Year    0.516382
# 1                           Area    0.336323
# 2                     Built year    0.079274
# 3                         Avgift    0.019907
# 4                          Month    0.017663
# 5                            Day    0.014495
# 6                   Lending rate    0.002755
# 7                   Deposit rate    0.002540
# 8                    Policy rate    0.002468
# 9                            Rum    0.002159
# 10                   Kolonnvägen    0.001788
# 11        Anders Lundströms gata    0.001752
# 12                      Frögatan    0.000466
# 13        Gustav III:s Boulevard    0.000453
# 14                Banmästargatan    0.000452
# 15                  Slåttervägen    0.000416
# 16                 Brevduvegatan    0.000203
# 17             Mäster Simons väg    0.000198
# 18                  Ballonggatan    0.000057
# 19                Signalistgatan    0.000056
# ...
